# %%
import pandas as pd

# %%
sub1 = pd.read_csv('/Users/semyonkuricyn/vs/RWB_ML/ML_solve/Semøn/data/submissions/submission_resnet+emb+catboost.csv')
sub2 = pd.read_csv('/Users/semyonkuricyn/vs/RWB_ML/ML_solve/Semøn/data/submissions/c79b92c4-434b-44d5-b865-3334536b36c0.csv')
sub3 = pd.read_csv('/Users/semyonkuricyn/vs/RWB_ML/ML_solve/Semøn/data/submissions/838c608b-a77f-414c-8e98-c46ad0a98eba.csv')

# %%
sub = sub1.copy()

# %%
a1 = sub1['y_pred'].to_numpy()
a2 = sub2['y_pred'].to_numpy()
a3 = sub3['y_pred'].to_numpy()

# %%
sub['y_pred'] = (a1 + a2 + a3) / 3

# %%
sub.to_csv('mid_sub.csv', index=False)
